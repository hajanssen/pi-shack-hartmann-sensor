# %%
import sys
sys.path.append("..")
import SHSlib  as sh
import cv2 as cv

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4682/3981019114.py in <module>
# ----> 1 del asd
#
# NameError: name 'asd' is not defined

# %%
import time
import picamera
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import cv2 as cv

class LivePlot():

    def __init__(self):
                 
        self.GeneratePlotFigures()
        
        self.t0 = time.time_ns()
        self.fig.canvas.draw()
        self.cam = picamera.PiCamera(sensor_mode= 4,  
                            resolution= resolution,
                            framerate= 30)
        
        
    def GeneratePlotFigures(self):
        # -- create Plot
        self.fig = plt.figure(figsize=(10,10))
        self.axSensor = self.fig.add_subplot(321)
        self.axPeakArea = self.fig.add_subplot(322)
        self.axIntegraion = self.fig.add_subplot(324)
        self.imageIntegraion = self.axIntegraion.imshow(PIL_ref_img)
        self.imageIntegraionColourbar = plt.colorbar(imageIntegraion)
        self.imageIntegraion.set_clim(-1500,1500)

        self.axPeakPosOverTime = self.fig.add_subplot(323)
        self.axPeakPosOverTime2 = self.fig.add_subplot(325)
        #axPeakPosOverTime2 = fig.add_subplot(211)

        self.imageSensorImg =  self.axSensor.imshow(PIL_ref_img)

        self.imagePeakArea = self.axPeakArea.imshow(ref_lables)
        self.linePeakPoints1 = self.axPeakArea.plot(ref_center[0],ref_center[1],"r.",label='refPos',linewidth=0.01,alpha=0.8)
        self.linePeakPoints2 = self.axPeakArea.plot(ref_center[0],ref_center[1],"b.",label='Pos',linewidth=0.01,alpha=0.4)
        self.axPeakArea.legend()

        self.linePeakPosOverXTime = []
        self.linePeakPosOverYTime = []
        for i in range(len(ref_center[0])):
            self.linePeakPosOverXTime += [self.axPeakPosOverTime.plot(ref_center[0][i])]
            self.linePeakPosOverYTime += [self.axPeakPosOverTime2.plot(ref_center[1][i])]
        
        plt.show()



        
        # Constuct Transformation Matrix "D" to be used with Gradientdatat G
        # the samplepositon for integration is equal for to the position of dots
        #self.D = sh.analyse.getIntegration(ref_center[0]*1.5e-6,ref_center[1]*1.5e-6,ref_center[0]*1.5e-6,ref_center[1]*1.5e-6,NPartner =7 )
    def getRawImage

# %%
with picamera.PiCamera(
    # Camera Setup 
    sensor_mode= 4,  
    resolution= resolution,
    framerate= 30
) as camera:
    # addition camera setup
    time.sleep(1)  # let the camera warm up and set gain/white balance
    camera.exposure_mode = 'off'
    camera.awb_mode = 'off'
    camera.awb_gains = 2.5

    camera.shutter_speed = int(6e6)
    camera.iso = 50
    LivePlot(camera)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4682/666200014.py in <module>
# ----> 1 LivePlot()
#
# /tmp/ipykernel_4682/2671773363.py in __init__(self)
#      11     def __init__(self):
#      12
# ---> 13         self.GeneratePlotFigures()
#      14
#      15
#
# /tmp/ipykernel_4682/2671773363.py in GeneratePlotFigures(self)
#      20         self.axPeakArea = self.fig.add_subplot(322)
#      21         self.axIntegraion = self.fig.add_subplot(324)
# ---> 22         self.imageIntegraion = self.axIntegraion.imshow(PIL_ref_img)
#      23         self.imageIntegraionColourbar = plt.colorbar(imageIntegraion)
#      24         self.imageIntegraion.set_clim(-1500,1500)
#
# NameError: name 'PIL_ref_img' is not defined
