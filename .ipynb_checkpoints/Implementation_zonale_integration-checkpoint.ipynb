# %% [markdown]
# # Implementation of Zonal Integration
# after: 2D zonal integration with unordered data, Greg A. Smith https://doi.org/10.1364/AO.426162

# %% [markdown]
# $ Z = D^+ \cdot G$
#
# $ D^+ = (D^T D)^{-^1}D^T $
#
# Z = desired shape
# G = Gradient data
# D = transformation Matrix

# %% [markdown]
# Indexing:
#
# $[x_k, y_k]$ = index of gradient data
#
# $[X_n, Y_n]$ = index of surface shape
#
# Defenition:
#
# $\Delta X_n = X_n - x_k$
#
# $\Delta Y_n = Y_n -y_k$

# %% [markdown]
# Matrix repesentation of Tylor expension of correction coeffication $c_n$
#
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>
#
# $V = M \cdot C$
#
# A valid solution only requires the number of Taylor terms must be less than or equal to the number of nearby points
#
# $C = M^+ \cdot V$
#
# $M^+ = (M^T M)^{-1} M^T$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import svds 
from scipy.linalg.interpolative import svd as isvd
from numpy.linalg import svd 
from numba import njit, prange


# set random seed to scramble the gradient locatoins
np.random.seed(0)

# define example data 
k = 20 # nuber gradient points'
xk_amp = np.linspace(0,2*np.pi,k+1) #+ np.random.rand(k+1) /4
yk_amp = np.linspace(0,2*np.pi,k+1) #+ np.random.rand(k+1) /4


# slice pos for gradint
xk_array = xk_amp[0:-1] + (xk_amp[1::] - xk_amp[0:-1])/2
yk_array = yk_amp[0:-1] + (yk_amp[1::] - yk_amp[0:-1])/2

G2x, G2y = np.meshgrid(xk_amp,yk_amp)

Gy_fun = lambda x: np.sin(x) #+ (x**2)/50
G_amp = Gy_fun(G2x) *  Gy_fun(G2y)


G_grad_x = np.diff(G_amp,axis=1)[1::,:]
G_grad_y = np.diff(G_amp,axis=0)[:,1::]

fig, ax = plt.subplots(1,3,figsize=(8,8),dpi=200)
ax[0].imshow(G_amp)
ax[0].set_title("Original Shape")

ax[1].imshow(G_grad_x)
ax[1].set_title("Gradient in X direction")

ax[2].imshow(G_grad_y)
ax[2].set_title("Gradient in Y direction")
plt.show()

# %%
def make1D(A):
    return np.reshape(A, A.shape[0] * A.shape[1])

# %%
# %%time
# xk yk : gradient position
# G : gradient Manitude

pinv = np.linalg.pinv

#pinv = linalg.pinv
# number of neighbouring points
P = 10

#1 construct vector Gvia Eq. (2)
G = np.concatenate([make1D(G_grad_x),make1D(G_grad_y)]) # append dy to dx like eqasion 2

#2 choose desired shape data locations [Xn,Yn]

n_res = 20
Xn_array = np.linspace(xk_array[0],xk_array[-1],n_res)
Yn_array = np.linspace(yk_array[0],yk_array[-1],n_res) 

Xn_2D, Yn_2D =  np.meshgrid(Xn_array,Yn_array)
Xn, Yn = make1D(Xn_2D), make1D(Yn_2D)

xk_array_1d, yk_array_1d =  np.meshgrid(xk_array,yk_array)
xk_array_1d, yk_array_1d = make1D(xk_array_1d), make1D(yk_array_1d)

# index where the Y array starts 
K = len(xk_array_1d)

# 
C = np.zeros((2*K, len(Xn) ))
#C = np.empty((2*K, len(Xn)))
#C[:,:] = np.NaN


#loop over all koordinates [1:100]
for i, (xk ,yk) in enumerate(zip(xk_array_1d, yk_array_1d)):
    # C = np.zeros((2*K, len(Xn)))
    # calculate distance to dots
    dX =  xk - Xn
    dY =  yk - Yn
    
    distance = np.sqrt(np.square(dX) + np.square(dY))
    distance_idx = np.argsort(distance)
    
    #plt.plot(xk,yk,"o")
    #plt.plot(Xn,Yn,"x")
    #plt.plot(Xn[distance_idx[0:P]],Yn[distance_idx[0:P]],"rx")

    # get closest P points 
    # dX = dX[distance_idx[0:P]]
    # dY = dY[distance_idx[0:P]]

    dX = Xn[distance_idx[0:P]] - xk
    dY = Yn[distance_idx[0:P]] - yk

    # --- X Components ---
    # taylor series Matrix
    M = np.array([np.ones(len(dX)), 
                  dX,
                  dY,#])
                  (dX**2)/2, 
                  dX*dY,
                  (dX**2)/2])

    # "Zero" Array with the number of Taylor polinom
    V = np.zeros((np.size(M,0),1))
    V[1] = 1
    
    M_pinv = pinv(M)
    
    C[i,distance_idx[0:P]] = (M_pinv @ V).T
    

    # # --- Y Components ---
    # # taylor series Matrix
    # M = np.array([np.ones(len(dX)), 
    #               dX,
    #               dY,
    #               (dX**2)/2, 
    #               dX*dY,
    #               (dX**2)/2])

    # "Zero" Array with the number of Taylor polinom
    V = np.zeros((np.size(M,0),1))
    V[2] = 1
    C[i+K,distance_idx[0:P]] = (M_pinv @ V).T
     
    
    # D = np.append(C, np.zeros((C.shape[0],1)), axis=1)
    # Z = pinv(D) @ G
    # Z_shape = np.reshape(Z[0:-1],(n_res,n_res))
    # plt.imshow(Z_shape, vmin=-1, vmax=1)
    # plt.show()
    # #plt.plot(xk,yk,".")
#empty_row = np.zeros((C.shape[0],1))
#empty_row[2] = 1

# D = np.append(C, empty_row, axis=1)
D = C
# Out:
# Wall time: 70.5 ms

# %%
# Sparceity of matix D
np.size(D[D == 0]) / np.size(D)
# Out:
# 0.975015625

# %%
# %%time
Z = np.linalg.pinv(D) @ G
# Out:
# Wall time: 44 ms

# %%
d32 = np.float32(D) 
g32 = np.float32(G)

# %%
# %%time
Z = np.linalg.pinv(d32) @ g32
# Out:
# Wall time: 46 ms

# %%
@njit
def crunch(A,B):
    return np.linalg.pinv(D) @ G

# %%
crunch(D,G)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-62-944cd735d444> in <module>
# ----> 1 crunch(D,G)
#
# ~\Anaconda3\lib\site-packages\numba\core\dispatcher.py in _compile_for_args(self, *args, **kws)
#     418                 e.patch_message(msg)
#     419
# --> 420             error_rewrite(e, 'typing')
#     421         except errors.UnsupportedError as e:
#     422             # Something unsupported is present in the user code, add help info
#
# ~\Anaconda3\lib\site-packages\numba\core\dispatcher.py in error_rewrite(e, issue_type)
#     359                 raise e
#     360             else:
# --> 361                 raise e.with_traceback(None)
#     362
#     363         argtypes = []
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# No implementation of function Function(<function lstsq at 0x0000016511A19EE0>) found for signature:
#
#  >>> lstsq(readonly array(float64, 2d, C), readonly array(float64, 1d, C), rcond=none)
#
# There are 2 candidate implementations:
#   - Of which 2 did not match due to:
#   Overload in function 'lstsq_impl': File: numba\np\linalg.py: Line 1583.
#     With argument(s): '(readonly array(float64, 2d, C), readonly array(float64, 1d, C), rcond=none)':
#    Rejected as the implementation raised a specific error:
#      TypingError: Failed in nopython mode pipeline (step: nopython frontend)
#    No implementation of function ExternalFunction(numba_ez_gelsd) found for signature:
#
#     >>> <unknown function>(Literal[int](100), int64, int64, Literal[int](1), ArrayCTypes(dtype=float64, ndim=2), int64, ArrayCTypes(dtype=float64, ndim=2), int64, ArrayCTypes(dtype=float64, ndim=1), none, ArrayCTypes(dtype=int32, ndim=1))
#
#    There are 2 candidate implementations:
#          - Of which 2 did not match due to:
#          Type Restricted Function in function 'unknown': File: unknown: Line unknown.
#            With argument(s): '(int64, int64, int64, int64, ArrayCTypes(dtype=float64, ndim=2), int64, ArrayCTypes(dtype=float64, ndim=2), int64, ArrayCTypes(dtype=float64, ndim=1), none, ArrayCTypes(dtype=int32, ndim=1))':
#           No match for registered cases:
#            * (int8, int64, int64, int64, float64*, int64, float64*, int64, float64*, float64, int32*) -> int32
#
#    During: resolving callee type: ExternalFunction(numba_ez_gelsd)
#    During: typing of call at C:\Users\hauke\Anaconda3\lib\site-packages\numba\np\linalg.py (1642)
#
#
#    File "..\..\..\..\Anaconda3\lib\site-packages\numba\np\linalg.py", line 1642:
#        def lstsq_impl(a, b, rcond=-1.0):
#            <source elided>
#
#            r = numba_ez_gelsd(
#            ^
#
#   raised from C:\Users\hauke\Anaconda3\lib\site-packages\numba\core\typeinfer.py:1071
#
# During: resolving callee type: Function(<function lstsq at 0x0000016511A19EE0>)
# During: typing of call at <ipython-input-61-a06c621bb2f5> (3)
#
#
# File "<ipython-input-61-a06c621bb2f5>", line 3:
# def crunch(A,B):
#     return np.linalg.lstsq(D,G,rcond=None)[0]
#     ^

# %%
# %%time
Z2 = np.linalg.lstsq(D,G,rcond=None)[0]
# Out:
# Wall time: 22.7 ms

# %%
# cmin = np.min(np.concatenate([make1D(G_amp),make1D(Z_shape)]))
# cmax = np.max(np.concatenate([make1D(G_amp),make1D(Z_shape)]))


# ax[0].imshow(G_amp, vmin=cmin, vmax=cmax , cmap='jet')
# ax[1].imshow(Z_shape, vmin=cmin, vmax=cmax, cmap='jet')
# ax[2].imshow(Z_shape-G_amp[1::,1::] , vmin=cmin, vmax=cmax,cmap='jet')
# plt.show()

# %%
#fig, ax = plt.subplots(1,3,figsize=(5,5),dpi=200)

#Z_shape = np.reshape(Z[0:-1],(n_res,n_res))
Z_shape = np.reshape(Z,(n_res,n_res))
Z2_shape = np.reshape(Z2,(n_res,n_res))

a= plt.imshow(G_amp); plt.colorbar(a)
plt.show()
a = plt.imshow(Z_shape); plt.colorbar(a)
plt.show()
a = plt.imshow(Z2_shape); plt.colorbar(a)
#plt.show()
#a = plt.imshow(Z_shape-G_amp[1::,1::]); plt.colorbar(a)

# %%
fig, ax = plt.subplots(1,2,figsize=(5,5),dpi=200)

Z_shape = -1*np.reshape(Z[0:-1],(n_res,n_res))



a = ax[0].imshow(G_amp); #plt.colorbar(a)
a = ax[1].imshow(Z_shape); #plt.colorbar(a)

# %% [markdown]
# # first test fith the matrix operations

# %%
# Sample points with the number of Parner
dX = np.linspace(0,10,5)
dY = np.linspace(0,10,5)

# taylor series Matrix
M = np.array([np.ones(len(dX)), 
              dX,
              dY,
              (dX**2)/2, 
              dX*dY,
              (dX**2)/2])

# "Zero" Array with the number of Taylor polinom
V = np.zeros((np.size(M,0),1))
V[1] = 1
print(V)
# Out:
# [[0.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]

# %%
C = np.linalg.pinv(M) @ V
